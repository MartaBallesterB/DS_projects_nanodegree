# %% [markdown]
# # <font color='#A533FF'>Module 1: Business Understanding</font>

# %% [markdown]
# AirBnB is an online-platform dedicated to the offer of accommodation to individuals and tourists (vacation rentals) through which hosts can advertise and contract the rental of their properties with their guests. For this project we will explore and analyze the AirBnB data of Valencia (Spain), a city on the shores of the Mediterranean Sea.
#
#
# #### Project Structure:
#
# The project follow the CRISP-DM Process (Cross Industry Process for Data Mining):
#
# 1. Business Understanding.
# 2. Data Understanding.
# 3. Data Preparation.
# 4. Data Modelling.
# 5. Result Evaluation.
# 6. Deployment (available on GitHub repository and Medium Blog Post only).
#
#
#
# #### Questions:
#
#
#
# - A. What are the busiest times of the year to visit Valencia? By how much do prices spike?
#
# - B. What type of airbnb is the most booked in the city? Where are they in the city?
#
# - C. How well can we predict the Airbnb price? What aspects correlate well to the price?

# %% [markdown]
# # <font color='#A533FF'>Module 2: Data Understanding</font>

# %% [markdown]
# I choose the following datasets, available on http://insideairbnb.com/get-the-data/, to answer the above questions:
#
# - calendar.csv: Contains information about [...].
#
# - listings.csv: Contains information about [...].
#
# ** DESCRIBIR VARIABLES E INFO CONTENIDA EN ESOS DATASETS

# %% [markdown]
# ### Importing libraries and loading the data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
calendar = pd.read_csv("calendar_2021.csv")
listings = pd.read_csv("listings.csv")

# %% [markdown]
# ### Exploring 'calendar' dataset

# %%
calendar.head()
# Out:
#    listing_id        date available   price adjusted_price  minimum_nights  \
# 0      193326  2021-06-28         t  $45.00         $45.00             1.0
# 1       48154  2021-06-28         f  $45.00         $45.00             3.0
# 2       48154  2021-06-29         f  $45.00         $45.00             3.0
# 3       48154  2021-06-30         f  $45.00         $45.00             3.0
# 4       48154  2021-07-01         f  $45.00         $45.00             3.0
#
#    maximum_nights
# 0          1125.0
# 1            25.0
# 2            25.0
# 3            25.0
# 4            25.0

# %%
print("The calendar dataset has " + str(calendar.shape[0]) + " rows and " + str(calendar.shape[1]) + " columns.")
# Out:
# The calendar dataset has 1981222 rows and 7 columns.

# %%
# Searching all the columns without missing values
no_nulls_calendar = set([calendar.columns[i] for i in range(0,7) if (calendar[(calendar.columns[i])].isna().sum() == 0)])
print(no_nulls_calendar)
# Out:
# {'date', 'available', 'listing_id'}

# %%
# Finding columns with more than 50% of their values missing
missing_cols_75_calendar = set(calendar.columns[calendar.isnull().mean() > 0.5])
print(missing_cols_75_calendar)
# Out:
# set()

# %%
# Finding columns with more than 2% of their values missing
calendar.columns[calendar.isnull().mean() > 0.02]
# Out:
# Index([], dtype='object')

# %% [markdown]
# It is shown that the **% of NaN values is less than 2%** of the total data available, so I proceed to drop the NaN values of this dataset (drop only the rows that contain NaN values for this columns).

# %%
calendar = calendar.dropna()
print("The new dataframe has " + str(calendar.shape[0]) + " rows and " + str(calendar.shape[1]) + " columns.")
# Out:
# The new dataframe has 1980083 rows and 7 columns.

# %%
calendar.dtypes
# Out:
# listing_id          int64
# date               object
# available          object
# price              object
# adjusted_price     object
# minimum_nights    float64
# maximum_nights    float64
# dtype: object

# %% [markdown]
# We observe that 'price' and 'adjusted_price' variables are shown as type object. It is needed to transform them to numeric as well as remove the dollar symbol in order to achieve it. We will see this later.

# %%
# Let's take a look at the summary statistics associated with the quantitative variables
calendar.describe()
# Out:
#          listing_id  minimum_nights  maximum_nights
# count  1.980083e+06    1.980083e+06    1.980083e+06
# mean   2.947914e+07    5.461517e+00    8.605985e+02
# std    1.443045e+07    1.708751e+01    4.628517e+02
# min    4.815400e+04    1.000000e+00    1.000000e+00
# 25%    1.813103e+07    2.000000e+00    3.650000e+02
# 50%    2.989972e+07    2.000000e+00    1.125000e+03
# 75%    4.267263e+07    4.000000e+00    1.125000e+03
# max    5.064875e+07    3.650000e+02    1.000000e+04

# %% [markdown]
# We can extract from this table that 5,45 nights are the mean of minimum nights and 8,6 the maximum nights available in this dataset for this population.

# %%
# Knowing the data period of time:
print("Dates are between " + min(calendar["date"]) + " and " + max(calendar["date"]) + ".")
# Out:
# Dates are between 2021-06-27 and 2022-06-28.

# %% [markdown]
# ### Exploring 'listings' dataset

# %%
listings.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   48154   https://www.airbnb.com/rooms/48154  20211218004345   2021-12-18
# 1   55692   https://www.airbnb.com/rooms/55692  20211218004345   2021-12-18
# 2   95393   https://www.airbnb.com/rooms/95393  20211218004345   2021-12-18
# 3  100347  https://www.airbnb.com/rooms/100347  20211218004345   2021-12-18
# 4  102524  https://www.airbnb.com/rooms/102524  20211218004345   2021-12-18
#
#                                                 name  \
# 0                           beautiful apartment wifi
# 1                             Delight in city center
# 2   Modern and bright Duplex 3 Bedrooms Center Wi-Fi
# 3  3BDR full Home at Sorolla station and Metro Jesús
# 4  EXCLUSIVE VILLA WITH POOL & 5 SUITES ON THE BEACH
#
#                                          description  \
# 0  <b>The space</b><br />Hello everybody and than...
# 1  A great place to stay and visit Valencia.<br /...
# 2  This is "Edificio Palomar Apartments", I will ...
# 3  Te va a encantar mi espacio por la ubicación y...
# 4  DO NOT PARTY OR STAG/HEN PARTIES! THE RESERVAT...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1                                                NaN
# 2  It is just 10 min walking distance to the Cath...
# 3  Barrio de Jesús, cercano al centro, zona conso...
# 4  Best restaurantes bars and clubs and chill out...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/1109085/9c0d4...   219476
# 1  https://a0.muscache.com/pictures/329316/a5d6a7...   120649
# 2  https://a0.muscache.com/pictures/931683/64aebc...   508042
# 3  https://a0.muscache.com/pictures/b0bb18e8-1f24...  1451371
# 4  https://a0.muscache.com/pictures/d2019707-1596...   535881
#
#                                     host_url  ... review_scores_communication  \
# 0   https://www.airbnb.com/users/show/219476  ...                        4.72
# 1   https://www.airbnb.com/users/show/120649  ...                        5.00
# 2   https://www.airbnb.com/users/show/508042  ...                        4.75
# 3  https://www.airbnb.com/users/show/1451371  ...                        4.89
# 4   https://www.airbnb.com/users/show/535881  ...                        4.61
#
#   review_scores_location review_scores_value     license instant_bookable  \
# 0                   4.44                4.52  VT-41540-V                f
# 1                   5.00                5.00         NaN                f
# 2                   4.75                4.67       31815                f
# 3                   4.80                4.65         NaN                f
# 4                   4.78                4.36  VT-36438-V                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              2                                           2
# 1                              1                                           1
# 2                              6                                           6
# 3                              1                                           1
# 4                              7                                           6
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            1
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.84
# 1                                           0              0.01
# 2                                           0              0.80
# 3                                           0              2.71
# 4                                           0              1.19
#
# [5 rows x 74 columns]

# %%
listings.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
print("The listings dataset has " + str(listings.shape[0]) + " rows and " + str(listings.shape[1]) + " columns.")
# Out:
# The listings dataset has 5546 rows and 74 columns.

# %%
# Searching all the columns without missing values
no_nulls_listings = set([listings.columns[i] for i in range(0,74) if (listings[(listings.columns[i])].isna().sum() == 0)])
print(no_nulls_listings)
# Out:
# {'calendar_last_scraped', 'longitude', 'name', 'id', 'minimum_nights_avg_ntm', 'has_availability', 'maximum_nights_avg_ntm', 'scrape_id', 'property_type', 'host_id', 'minimum_minimum_nights', 'maximum_nights', 'accommodates', 'calculated_host_listings_count_entire_homes', 'neighbourhood_cleansed', 'maximum_maximum_nights', 'price', 'minimum_nights', 'availability_365', 'number_of_reviews_l30d', 'calculated_host_listings_count_private_rooms', 'listing_url', 'availability_60', 'number_of_reviews', 'latitude', 'calculated_host_listings_count', 'neighbourhood_group_cleansed', 'instant_bookable', 'calculated_host_listings_count_shared_rooms', 'availability_30', 'host_verifications', 'last_scraped', 'minimum_maximum_nights', 'availability_90', 'picture_url', 'room_type', 'maximum_minimum_nights', 'amenities', 'number_of_reviews_ltm', 'host_url'}

# %%
print("The listings dataset has " + str(len(no_nulls_listings)) + " columns without missing values.")
# Out:
# The listings dataset has 40 columns without missing values.

# %%
# Finding columns with more than 50% of their values missing
missing_cols_75_listings = set(listings.columns[listings.isnull().mean() > 0.50])
print(missing_cols_75_listings)
# Out:
# {'host_neighbourhood', 'calendar_updated', 'license', 'bathrooms'}

# %%
# Finding columns with more than 95% of their values missing
missing_cols_90 = listings.columns[listings.isnull().mean() > 0.95]
print(missing_cols_90)
# Out:
# Index(['bathrooms', 'calendar_updated'], dtype='object')

# %% [markdown]
# The 'bathroom' and 'calendar_updated' variables have more than 95% of missing values. It is observed that the 'bathrooms_text' variable contains the number of bathrooms available in the houses, so I decided to drop it from the dataset. Furthermore, the 'calendar_updated' column has no values (100% of missing data) so I will also drop it.
#
# On the other hand, the 'license' and 'neighbourhood_group_cleansed' column have more than 50% of missing values. I decided to drop them from the exploratory because 'license' it does not give me valuable information to solve the questions and 'neighbourhood_group_cleansed' variable gives me the information that is missing in 'host_neighbourhood'.

# %%
listings = listings.drop(columns=['bathrooms', 'calendar_updated', 'license', 'host_neighbourhood'])
print("The new dataframe has " + str(listings.shape[0]) + " rows and " + str(listings.shape[1]) + " columns.")
# Out:
# The new dataframe has 5546 rows and 70 columns.

# %%
listings.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  5.546000e+03  5.546000e+03  5.546000e+03          5545.000000
# mean   3.203663e+07  2.021122e+13  1.444750e+08            16.371867
# std    1.568328e+07  1.937675e+00  1.307299e+08           136.443721
# min    4.815400e+04  2.021122e+13  5.947000e+03             0.000000
# 25%    1.918170e+07  2.021122e+13  3.253363e+07             1.000000
# 50%    3.295835e+07  2.021122e+13  1.028993e+08             2.000000
# 75%    4.663667e+07  2.021122e+13  2.260539e+08             6.000000
# max    5.387368e+07  2.021122e+13  4.362986e+08          3750.000000
#
#        host_total_listings_count     latitude    longitude  accommodates  \
# count                5545.000000  5546.000000  5546.000000   5546.000000
# mean                   16.371867    39.467737    -0.364004      3.646953
# std                   136.443721     0.022815     0.023157      2.033743
# min                     0.000000    39.279330    -0.427840      1.000000
# 25%                     1.000000    39.462950    -0.379647      2.000000
# 50%                     2.000000    39.470020    -0.371835      4.000000
# 75%                     6.000000    39.475700    -0.345225      5.000000
# max                  3750.000000    39.562660    -0.276100     16.000000
#
#           bedrooms         beds  ...  review_scores_cleanliness  \
# count  5252.000000  5429.000000  ...                4793.000000
# mean      1.791698     2.433782  ...                   4.613207
# std       0.994377     1.669520  ...                   0.486661
# min       1.000000     1.000000  ...                   1.000000
# 25%       1.000000     1.000000  ...                   4.500000
# 50%       1.000000     2.000000  ...                   4.750000
# 75%       2.000000     3.000000  ...                   4.920000
# max      10.000000    22.000000  ...                   5.000000
#
#        review_scores_checkin  review_scores_communication  \
# count            4793.000000                  4793.000000
# mean                4.790532                     4.776192
# std                 0.403178                     0.405643
# min                 1.000000                     1.000000
# 25%                 4.770000                     4.740000
# 50%                 4.900000                     4.900000
# 75%                 5.000000                     5.000000
# max                 5.000000                     5.000000
#
#        review_scores_location  review_scores_value  \
# count             4793.000000          4793.000000
# mean                 4.711890             4.573605
# std                  0.379884             0.469426
# min                  1.000000             1.000000
# 25%                  4.600000             4.470000
# 50%                  4.810000             4.680000
# 75%                  4.960000             4.830000
# max                  5.000000             5.000000
#
#        calculated_host_listings_count  \
# count                     5546.000000
# mean                         9.388749
# std                         23.598115
# min                          1.000000
# 25%                          1.000000
# 50%                          2.000000
# 75%                          6.000000
# max                        140.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                  5546.000000
# mean                                      7.994410
# std                                      23.285203
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       1.000000
# 75%                                       4.000000
# max                                     137.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                   5546.000000
# mean                                       1.360079
# std                                        3.343457
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        1.000000
# max                                       28.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                  5546.000000        4819.000000
# mean                                      0.010458           1.373077
# std                                       0.175811           1.333834
# min                                       0.000000           0.010000
# 25%                                       0.000000           0.370000
# 50%                                       0.000000           0.980000
# 75%                                       0.000000           2.000000
# max                                       5.000000          13.040000
#
# [8 rows x 37 columns]

# %% [markdown]
# We can observe that 1 and 10 are the minimum and maximum of bedrooms in all the rents of the dataset. We can also extract that the review scores are in the range 1-5.

# %%
# Constructing some histograms to visualize the distrubution of the variables below
listings[['bedrooms', 'beds', 'availability_30', 'availability_60']].hist()
# Out:
# array([[<AxesSubplot:title={'center':'bedrooms'}>,
#         <AxesSubplot:title={'center':'beds'}>],
#        [<AxesSubplot:title={'center':'availability_30'}>,
#         <AxesSubplot:title={'center':'availability_60'}>]], dtype=object)

# %%
# Extracting what type of neighbourhoods are in the city and its count
neighbourhood_counts = listings["neighbourhood_group_cleansed"].value_counts().reset_index()

# %%
# Representing the total of bookings per neighbourhood
sns.set_theme(style="whitegrid")
sns.set(rc={'figure.figsize':(12, 8)})
ax = sns.barplot(x= "neighbourhood_group_cleansed", y = "index", data = neighbourhood_counts, palette="Blues_d").set(title='Total Nº of bookings by neighbourhood')
plt.xlabel('Nº of bookings')
plt.ylabel('Neighbourhooods')
plt.show()

# %% [markdown]
# Ciutat Vella and Poblats Marítims are the most requested neighbourhoods by the users for this period of time. Moreover, Ciutat Vella has the double of bookings than the other 17 neighbourhoods.

# %% [markdown]
# # <font color='#A533FF'>Module 3: Data Preparation</font>

# %% [markdown]
# ### 1. What are the busiest times of the year to rent a room in Valencia? By how much do prices spike?

# %% [markdown]
# In order to answer this question, it si needed to extract all the available rents during our data period of time

# %% [markdown]
# To represent availability through time we need the 'available' column of the dataset that is True ('t') and then plot it with the dates.

# %%
calendar.head()
# Out:
#    listing_id        date available   price adjusted_price  minimum_nights  \
# 0      193326  2021-06-28         t  $45.00         $45.00             1.0
# 1       48154  2021-06-28         f  $45.00         $45.00             3.0
# 2       48154  2021-06-29         f  $45.00         $45.00             3.0
# 3       48154  2021-06-30         f  $45.00         $45.00             3.0
# 4       48154  2021-07-01         f  $45.00         $45.00             3.0
#
#    maximum_nights
# 0          1125.0
# 1            25.0
# 2            25.0
# 3            25.0
# 4            25.0

# %%
calendar['available'] = calendar['available'] == 'f'
calendar['month'] = pd.DatetimeIndex(calendar['date']).month
calendar.groupby('month')['available'].mean().plot(title = 'Valencia Airbnb availability rate by month')
# Out:
# <AxesSubplot:title={'center':'Valencia Airbnb availability rate by month'}, xlabel='month'>

# %% [markdown]
# Taking into account that the time period of our data is from 2021-06-27 and 2022-06-28, we observe that [...]

# %%
calendar['price'] = calendar['price'].replace('[\$,]', '', regex=True).astype(float)
calendar['month'] = pd.DatetimeIndex(calendar['date']).month

ax2 = calendar.groupby('month')['price'].mean().plot(title='Valencia Airbnb price by month')
ax2.set_ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %% [markdown]
# [REHACER!!!!!]Summer months (July and August) are the most expensive of the year, over $138/ night. A peak is observed in March, month when Fallas are celebrated and also there is a peak in November.

# %% [markdown]
# ### 2.  What type of airbnb is the most booked in the city? Where are they in the city?

# %% [markdown]
# # <font color='#A533FF'>Module 4: Data Modelling</font>

# %% [markdown]
# ### Question 3. How well can we predict the Airbnb price? What aspects correlate well to the price?

# %% [markdown]
# **'host_response_rate', 'host_acceptance_rate' -> en porcentajes + nan -> convertir a int y mirar % NaN**
#
# **'bathrooms_text' -> quedarse solo con los numeros**
#
# **'property_type', 'room_type' -> texto pero estaria guay sacar datos**

# %% [markdown]
# - Observing all the variables in the dataset, I decided to choose the following columns to construct the model:
#
#     'review_scores_rating', 'review_scores_accuracy','review_scores_cleanliness', 'review_scores_checkin',
#     'review_scores_communication', 'review_scores_location','review_scores_value', 'accommodates', 'bedrooms',
#     'beds', 'price','minimum_nights', 'maximum_nights', 'minimum_minimum_nights', 'maximum_minimum_nights',
#     'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm',
#     'availability_365', 'number_of_reviews', 'instant_bookable', 'host_is_superhost', 'host_has_profile_pic',
#     'host_identity_verified', 'host_response_rate', 'host_acceptance_rate', 'bathrooms_text'

# %%
listings_3 = listings[['review_scores_rating', 'review_scores_accuracy','review_scores_cleanliness', 'review_scores_checkin',
                       'review_scores_communication', 'review_scores_location','review_scores_value', 'accommodates', 'bedrooms',
                       'beds', 'price','minimum_nights', 'maximum_nights', 'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights',
                       'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'availability_365', 'number_of_reviews',
                       'instant_bookable', 'host_is_superhost', 'host_identity_verified', 'host_response_rate',
                       'host_acceptance_rate', 'bathrooms_text']]

print("The listings dataset to construct the model " + str(listings_3.shape[1]) + " columns.")
# Out:
# The listings dataset to construct the model 27 columns.

# %%
listings_3.describe()
# Out:
#        review_scores_rating  review_scores_accuracy  \
# count           4819.000000             4793.000000
# mean               4.586510                4.711162
# std                0.574609                0.428752
# min                0.000000                1.000000
# 25%                4.500000                4.640000
# 50%                4.720000                4.830000
# 75%                4.890000                4.940000
# max                5.000000                5.000000
#
#        review_scores_cleanliness  review_scores_checkin  \
# count                4793.000000            4793.000000
# mean                    4.613207               4.790532
# std                     0.486661               0.403178
# min                     1.000000               1.000000
# 25%                     4.500000               4.770000
# 50%                     4.750000               4.900000
# 75%                     4.920000               5.000000
# max                     5.000000               5.000000
#
#        review_scores_communication  review_scores_location  \
# count                  4793.000000             4793.000000
# mean                      4.776192                4.711890
# std                       0.405643                0.379884
# min                       1.000000                1.000000
# 25%                       4.740000                4.600000
# 50%                       4.900000                4.810000
# 75%                       5.000000                4.960000
# max                       5.000000                5.000000
#
#        review_scores_value  accommodates     bedrooms         beds  \
# count          4793.000000   5546.000000  5252.000000  5429.000000
# mean              4.573605      3.646953     1.791698     2.433782
# std               0.469426      2.033743     0.994377     1.669520
# min               1.000000      1.000000     1.000000     1.000000
# 25%               4.470000      2.000000     1.000000     1.000000
# 50%               4.680000      4.000000     1.000000     2.000000
# 75%               4.830000      5.000000     2.000000     3.000000
# max               5.000000     16.000000    10.000000    22.000000
#
#        minimum_nights  maximum_nights  minimum_minimum_nights  \
# count     5546.000000     5546.000000             5546.000000
# mean         6.175081      715.492968                6.354670
# std         27.997684      509.059083               27.576899
# min          1.000000        1.000000                1.000000
# 25%          1.000000       90.000000                2.000000
# 50%          2.000000     1125.000000                2.000000
# 75%          3.000000     1125.000000                3.000000
# max       1000.000000    10000.000000             1000.000000
#
#        maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# count             5546.000000             5546.000000             5546.000000
# mean                 7.765417              851.737649              869.729715
# std                 28.750893              460.993309              450.395077
# min                  1.000000                1.000000                1.000000
# 25%                  2.000000              365.000000              365.000000
# 50%                  3.000000             1125.000000             1125.000000
# 75%                  5.000000             1125.000000             1125.000000
# max               1000.000000            10000.000000            10000.000000
#
#        minimum_nights_avg_ntm  maximum_nights_avg_ntm  availability_365  \
# count             5546.000000             5546.000000       5546.000000
# mean                 7.050811              865.370754        175.007212
# std                 28.243888              451.091347        128.447881
# min                  1.000000                1.000000          0.000000
# 25%                  2.000000              365.000000         58.000000
# 50%                  2.000000             1125.000000        168.000000
# 75%                  4.000000             1125.000000        304.000000
# max               1000.000000            10000.000000        365.000000
#
#        number_of_reviews
# count        5546.000000
# mean           41.281825
# std            65.298773
# min             0.000000
# 25%             3.000000
# 50%            13.000000
# 75%            51.000000
# max           678.000000

# %%
# Checking the % of data we have available in each column
print(1 - listings_3.isnull().mean())
# Out:
# review_scores_rating           0.868915
# review_scores_accuracy         0.864226
# review_scores_cleanliness      0.864226
# review_scores_checkin          0.864226
# review_scores_communication    0.864226
# review_scores_location         0.864226
# review_scores_value            0.864226
# accommodates                   1.000000
# bedrooms                       0.946989
# beds                           0.978904
# price                          1.000000
# minimum_nights                 1.000000
# maximum_nights                 1.000000
# minimum_minimum_nights         1.000000
# maximum_minimum_nights         1.000000
# minimum_maximum_nights         1.000000
# maximum_maximum_nights         1.000000
# minimum_nights_avg_ntm         1.000000
# maximum_nights_avg_ntm         1.000000
# availability_365               1.000000
# number_of_reviews              1.000000
# instant_bookable               1.000000
# host_is_superhost              0.999820
# host_identity_verified         0.999820
# host_response_rate             0.884962
# host_acceptance_rate           0.937252
# bathrooms_text                 0.999279
# dtype: float64

# %% [markdown]
# We observe that the maximum % of NaN in the dataset is around 13% (the first 6 variables related to review scores). Seeing the distribution of the values of this columns (describe function) I decide to imputing this values with the mean of each column.

# %%
# Imputing the mean for the first 6 columns of the 'listings_3' subset:
fill_mean = lambda col: col.fillna(col.mean())

try:
    listings_3.iloc[:,0:7].apply(fill_mean, axis=0)
except:
    print('That broke :(')

# %%
# Checking the % of values for each column again
print(1 - listings_3.isnull().mean())
# Out:
# review_scores_rating           0.868915
# review_scores_accuracy         0.864226
# review_scores_cleanliness      0.864226
# review_scores_checkin          0.864226
# review_scores_communication    0.864226
# review_scores_location         0.864226
# review_scores_value            0.864226
# accommodates                   1.000000
# bedrooms                       0.946989
# beds                           0.978904
# price                          1.000000
# minimum_nights                 1.000000
# maximum_nights                 1.000000
# minimum_minimum_nights         1.000000
# maximum_minimum_nights         1.000000
# minimum_maximum_nights         1.000000
# maximum_maximum_nights         1.000000
# minimum_nights_avg_ntm         1.000000
# maximum_nights_avg_ntm         1.000000
# availability_365               1.000000
# number_of_reviews              1.000000
# instant_bookable               1.000000
# host_is_superhost              0.999820
# host_identity_verified         0.999820
# host_response_rate             0.884962
# host_acceptance_rate           0.937252
# bathrooms_text                 0.999279
# dtype: float64

# %% [markdown]
# For all the other columns with a little % of NaN, I decided to drop them of the dataset.

# %%
listings_3 = listings_3.dropna()
# We have all the columns without NaN values
listings_3.isnull().sum()
# Out:
# review_scores_rating           0
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# review_scores_value            0
# accommodates                   0
# bedrooms                       0
# beds                           0
# price                          0
# minimum_nights                 0
# maximum_nights                 0
# minimum_minimum_nights         0
# maximum_minimum_nights         0
# minimum_maximum_nights         0
# maximum_maximum_nights         0
# minimum_nights_avg_ntm         0
# maximum_nights_avg_ntm         0
# availability_365               0
# number_of_reviews              0
# instant_bookable               0
# host_is_superhost              0
# host_identity_verified         0
# host_response_rate             0
# host_acceptance_rate           0
# bathrooms_text                 0
# dtype: int64

# %%
print("The filtered dataset has " + str(listings_3.shape[0]) + " rows and " + str(listings_3.shape[1]) + " columns.")
# Out:
# The filtered dataset has 3971 rows and 27 columns.

# %% [markdown]
# Now, it is needed to check the types of the columns and convert them if needed:

# %%
listings_3.dtypes
# Out:
# review_scores_rating           float64
# review_scores_accuracy         float64
# review_scores_cleanliness      float64
# review_scores_checkin          float64
# review_scores_communication    float64
# review_scores_location         float64
# review_scores_value            float64
# accommodates                     int64
# bedrooms                       float64
# beds                           float64
# price                          float64
# minimum_nights                   int64
# maximum_nights                   int64
# minimum_minimum_nights           int64
# maximum_minimum_nights           int64
# minimum_maximum_nights           int64
# maximum_maximum_nights           int64
# minimum_nights_avg_ntm         float64
# maximum_nights_avg_ntm         float64
# availability_365                 int64
# number_of_reviews                int64
# instant_bookable                 int64
# host_is_superhost                int64
# host_identity_verified           int64
# host_response_rate             float64
# host_acceptance_rate           float64
# bathrooms_text                  object
# dtype: object

# %% [markdown]
# **a)** The variables *'instant_bookable', 'host_is_superhost', 'host_identity_verified'* are boolean, so let's explore more and change the f/t values into 0/1:

# %%
listings_3[['instant_bookable', 'host_is_superhost', 'host_identity_verified']] = listings_3[['instant_bookable', 'host_is_superhost', 'host_identity_verified']].replace({"t": 1, "f": 0})

# %% [markdown]
# **b)** The 'host_response_rate', 'host_acceptance_rate' and 'price' variables are object type and it is needed to convert them to numeric type:

# %%
# Convert to numerical the 'price' variable and drop the dollar and % symbol
listings_3['price'] = listings_3.loc[:,'price'].replace('[\$,]', '', regex=True).astype(float)
listings_3['host_response_rate'] = listings_3.loc[:,'host_response_rate'].replace('[\%,]', '', regex=True).astype(float)
listings_3['host_acceptance_rate'] = listings_3.loc[:,'host_acceptance_rate'].replace('[\%,]', '', regex=True).astype(float)

# %% [markdown]
# **c)** Drop text in the 'bathrooms_text' variable:

# %%
listings_3['bathrooms_text'] = listings_3.loc[:,'bathrooms_text'].str.split(' ').str[0]
listings_3['bathrooms_text'] = listings_3.loc[:,'bathrooms_text'].replace('Half-bath', 0.5, regex=True).astype(float)
# Visualize different number of bathrooms and checking anomalies
listings_3['bathrooms_text'].value_counts()
# Out:
# 1.0    2520
# 2.0     822
# 1.5     472
# 2.5      69
# 3.0      50
# 0.0      11
# 3.5       9
# 4.0       7
# 5.0       4
# 4.5       2
# 0.5       2
# 5.5       1
# 7.0       1
# 6.5       1
# Name: bathrooms_text, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(18,18))
sns.heatmap(listings_3.corr(), annot = True, fmt = ".2f", ax= ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # <font color='#A533FF'>Module 5: Result Evaluation</font>

# %% [markdown]
# # <font color='#A533FF'>Module 6: Deployment </font>

# %% [markdown]
# This section is available on the following sites:
#
# [...]
